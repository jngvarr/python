# %%
f(x)= 5x^2+10x-30
# Out:
#   File "C:\Users\itereshechkin\AppData\Local\Temp\ipykernel_13456\827129553.py", line 1
#     f(x)= 5x^2+10x-30
#     ^
# SyntaxError: cannot assign to function call

# %%
from sympy import*

# %%
import math

# %%
from sympy.plotting import plot

# %%
import random

# %%
x = Symbol ('x')
fx = 5*x**2+10*x-30
fx
# Out:
# 5*x**2 + 10*x - 30

# %%
p= plot (fx, (x,-10,10))
